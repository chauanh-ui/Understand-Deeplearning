# %% [markdown]
# <a href="https://colab.research.google.com/github/chauanh-ui/Understand-Deeplearning/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-r8viv6iq
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-r8viv6iq
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=c5ed5cce7978c9a9afe473982b180eff85f16f94f9d7ab760b3c60714339f9c3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wi3cm3ob/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(
nn.Linear(D_i, D_k),
nn.ReLU(),
nn.Linear(D_k, D_k),
nn.ReLU(),
nn.Linear(D_k, D_k),
nn.ReLU(),
nn.Linear(D_k, D_o))


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=200, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.697195, train error 68.20,  test loss 1.733363, test error 70.90
# Epoch     1, train loss 1.507166, train error 55.95,  test loss 1.620520, test error 63.40
# Epoch     2, train loss 1.348022, train error 50.33,  test loss 1.496147, test error 59.00
# Epoch     3, train loss 1.199410, train error 44.72,  test loss 1.423647, test error 55.90
# Epoch     4, train loss 1.072338, train error 39.40,  test loss 1.339852, test error 53.70
# Epoch     5, train loss 0.989537, train error 35.45,  test loss 1.293927, test error 51.00
# Epoch     6, train loss 0.882466, train error 30.47,  test loss 1.235715, test error 49.10
# Epoch     7, train loss 0.797854, train error 27.72,  test loss 1.264889, test error 47.20
# Epoch     8, train loss 0.719389, train error 25.28,  test loss 1.253071, test error 46.10
# Epoch     9, train loss 0.643864, train error 21.60,  test loss 1.217573, test error 45.90
# Epoch    10, train loss 0.551718, train error 17.45,  test loss 1.175194, test error 44.70
# Epoch    11, train loss 0.501110, train error 15.22,  test loss 1.180951, test error 43.40
# Epoch    12, train loss 0.469214, train error 14.30,  test loss 1.181579, test error 41.80
# Epoch    13, train loss 0.433378, train error 13.32,  test loss 1.204542, test error 42.70
# Epoch    14, train loss 0.389712, train error 10.35,  test loss 1.211773, test error 42.60
# Epoch    15, train loss 0.359807, train error 9.50,  test loss 1.247472, test error 43.00
# Epoch    16, train loss 0.328512, train error 8.57,  test loss 1.216455, test error 41.50
# Epoch    17, train loss 0.299408, train error 7.55,  test loss 1.264131, test error 41.40
# Epoch    18, train loss 0.270652, train error 6.22,  test loss 1.278888, test error 41.70
# Epoch    19, train loss 0.241739, train error 5.07,  test loss 1.291930, test error 42.60
# Epoch    20, train loss 0.214826, train error 3.25,  test loss 1.285811, test error 40.90
# Epoch    21, train loss 0.205628, train error 3.62,  test loss 1.298636, test error 42.10
# Epoch    22, train loss 0.193748, train error 3.00,  test loss 1.325890, test error 41.00
# Epoch    23, train loss 0.183367, train error 2.90,  test loss 1.332828, test error 41.70
# Epoch    24, train loss 0.172827, train error 2.45,  test loss 1.346076, test error 41.60
# Epoch    25, train loss 0.161508, train error 2.18,  test loss 1.365269, test error 41.00
# Epoch    26, train loss 0.152634, train error 1.85,  test loss 1.370118, test error 40.30
# Epoch    27, train loss 0.145786, train error 1.55,  test loss 1.386832, test error 40.90
# Epoch    28, train loss 0.138392, train error 1.60,  test loss 1.401249, test error 40.60
# Epoch    29, train loss 0.130366, train error 1.00,  test loss 1.426825, test error 41.10
# Epoch    30, train loss 0.124832, train error 1.00,  test loss 1.422211, test error 40.50
# Epoch    31, train loss 0.120420, train error 1.03,  test loss 1.426313, test error 40.70
# Epoch    32, train loss 0.117077, train error 0.90,  test loss 1.437655, test error 40.30
# Epoch    33, train loss 0.113756, train error 0.97,  test loss 1.438409, test error 40.40
# Epoch    34, train loss 0.112087, train error 0.72,  test loss 1.453372, test error 40.50
# Epoch    35, train loss 0.107831, train error 0.75,  test loss 1.458713, test error 40.30
# Epoch    36, train loss 0.104647, train error 0.62,  test loss 1.459688, test error 40.10
# Epoch    37, train loss 0.102116, train error 0.62,  test loss 1.460693, test error 40.10
# Epoch    38, train loss 0.098589, train error 0.53,  test loss 1.474473, test error 39.70
# Epoch    39, train loss 0.096516, train error 0.47,  test loss 1.485922, test error 40.20
# Epoch    40, train loss 0.094666, train error 0.45,  test loss 1.481596, test error 39.90
# Epoch    41, train loss 0.093342, train error 0.53,  test loss 1.487702, test error 39.80
# Epoch    42, train loss 0.092109, train error 0.45,  test loss 1.491533, test error 39.60
# Epoch    43, train loss 0.090737, train error 0.45,  test loss 1.491820, test error 39.70
# Epoch    44, train loss 0.090276, train error 0.40,  test loss 1.494574, test error 40.40
# Epoch    45, train loss 0.088479, train error 0.43,  test loss 1.503055, test error 39.90
# Epoch    46, train loss 0.087405, train error 0.43,  test loss 1.503506, test error 39.90
# Epoch    47, train loss 0.086202, train error 0.38,  test loss 1.505667, test error 40.00
# Epoch    48, train loss 0.085307, train error 0.30,  test loss 1.511574, test error 39.70
# Epoch    49, train loss 0.084090, train error 0.35,  test loss 1.516865, test error 39.70

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
